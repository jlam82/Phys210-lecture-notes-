# %%
x = 1
if not (x < 10 and x > 1):
    print("hi")
else:
    print("bye")
# Out:
# hi

# %%
r = [10, 20, 30]
print(r[-1])
# Out:
# 30

# %%
r = [10, 20, 30, 40, 50]
s = r[2:4]
print(s)

q = r[2:5]
print(q)

r[5]
# so there does not exists 5 as an index, but it can be used in splicing to reach the last index
# Out:
# [30, 40]
# [30, 40, 50]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17412\3042991409.py in <module>
#       6 print(q)
#       7
# ----> 8 r[5]
#
# IndexError: list index out of range

# %%
print(r[2:-1])
print(r[2:])
# Out:
# [30, 40]
# [30, 40, 50]

# %%
l1 = [1, 2, 3]
l2 = [2, 3, 4]
l3 = l1 + l2
print(l3)

l4 = 3*l1
print(l4)
# not very useful for physics representation like vectors
# Out:
# [1, 2, 3, 2, 3, 4]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# Homework 1 Problem 1.1

# %%
def fact(n):
    i = n
    while n>1:
        n -= 1
        i = i*n
    return i

fact(4)
# Out:
# 24

# %%
# This code tests that your Python installation worked. 
# It generates a png image file that you should e-mail
# to the address shown on the plot

import scipy
import numpy
import matplotlib
import matplotlib.pyplot as plt
import platform
import socket

# If you are a student, please fill in your first and last
# names inside the quotes in the two lines below. Do not
# modify anything else in this file.
your_first_name = 'Jeff'
your_last_name = 'Lam'

#------------------------------------------------------
classname = '210_Programming_in_Physics'
term = 'Fall_2023'              # must contain no spaces
email = 'slevy@binghamton.edu'
plt.plot([0,1], 'r', [1,0], 'b')
plt.text( 0.5, 0.8, '{0:s} {1:s}'.format(your_first_name, your_last_name),
        horizontalalignment='center',
        size = 'x-large',
        bbox=dict(facecolor='purple', alpha=0.4))
plt.text( 0.5, 0.05,
        '{0:s}\n{1:s}\nscipy {2:s}\nnumpy {3:s}\nmatplotlib {4:s}\non {5:s}\n{6:s}'.format(
        classname,
        term,
        scipy.__version__,
        numpy.__version__,
        matplotlib.__version__,
        platform.platform(),
        socket.gethostname()
        ) ,
      horizontalalignment='center'
      )
filename = your_last_name + '_' + your_first_name + '_' + term + '.png'
plt.title('*** Upload the saved version of this plot with HW1, ***\n' +
        '"{0:s}"'.format(filename), fontsize=12)
plt.savefig(filename)
plt.show()
